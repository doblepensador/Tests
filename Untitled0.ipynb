# %% [markdown]
# <a href="https://colab.research.google.com/github/doblepensador/Tests/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import multiprocessing
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline, Pipeline

# %%
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# #KNN Classification

# %% [markdown]
# ## Example 1 - Iris - KNN Classifier

# %%
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test) # Fit된 결과를 갖고, transform만 해 주면 된다!

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)

print("Score for the train set: {}".format(model.score(X_train, y_train)))
print("Score for the test set: {}".format(model.score(X_test, y_test)))
# Out:
# Score for the train set: 0.975
# Score for the test set: 0.9666666666666667

# %%
model = KNeighborsClassifier()
model.fit(X_train_scale, y_train)

print("Score for the train set: {}".format(model.score(X_train_scale, y_train)))
print("Score for the test set: {}".format(model.score(X_test_scale, y_test)))
# Out:
# Score for the train set: 0.9583333333333334
# Score for the test set: 0.9666666666666667

# %%
cross_validate(estimator=KNeighborsClassifier(), X=X, y=y, cv=5,
               n_jobs=multiprocessing.cpu_count(),
               verbose=True)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   5 out of   5 | elapsed:    1.3s finished
# {'fit_time': array([0.00135612, 0.00148582, 0.00123763, 0.00096011, 0.001091  ]),
#  'score_time': array([0.0030551 , 0.00298214, 0.00290346, 0.00269222, 0.00311375]),
#  'test_score': array([0.96666667, 1.        , 0.93333333, 0.96666667, 1.        ])}

# %%
param = {'n_neighbors' : [3,5,7],
         'weights' : ('uniform','distance'),'algorithm' : ('ball_tree','kd_tree','brute')}
#Weight: 가까이에 위치한 것에 따라 가중치(weight)를 많이주는 방법

gs = GridSearchCV(
    estimator = KNeighborsClassifier(),
    param_grid = param,
    n_jobs = multiprocessing.cpu_count(),
    cv = 5,
    verbose = True
)

gs.fit(X, y)
print("best estimator:{}, best score: {}".format(gs.best_estimator_, gs.best_score_))
#KNeighborsClassifier(algorithm='ball_tree', n_neighbors=7)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# best estimator:KNeighborsClassifier(algorithm='ball_tree', n_neighbors=7), best score: 0.9800000000000001

# %%
model = KNeighborsClassifier(algorithm='ball_tree', n_neighbors=7)

# %%
def make_meshgrid(x, y, h= 0.02):
  x_min, x_max = x.min()-1, x.max()+1
  y_min, y_max = y.min()-1, y.max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                       np.arange(y_min, y_max, h))
  return xx, yy

# %%
def plot_contours(clf, xx, yy, **params):
  Z = clf.predict(np.column_stack([xx.ravel(), yy.ravel()]))
  Z = Z.reshape(xx.shape)
  out = plt.contourf(xx, yy, Z, **params)
  return out

# %%
t_SNE = TSNE(n_components=2)
X_comp = t_SNE.fit_transform(X)
X0, X1 = X_comp[:,0], X_comp[:,1]
xx, yy = make_meshgrid(X0, X1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
model.fit(X_comp, y)
plot_contours(model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.7)
plt.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k');

# %% [markdown]
# ## Example 2 - Breast Cancer - KNN Classifier

# %%
# Breast cancer
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)

print("Score for the train set: {}".format(model.score(X_train, y_train)))
print("Score for the test set: {}".format(model.score(X_test, y_test)))
# Out:
# Score for the train set: 0.9428571428571428
# Score for the test set: 0.9385964912280702

# %%
estimator = make_pipeline(
    StandardScaler(),
    KNeighborsClassifier()
)

cross_validate(estimator=estimator, X=X, y=y, cv=5,
               n_jobs=multiprocessing.cpu_count(),
               verbose=True)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   5 out of   5 | elapsed:    1.5s finished
# {'fit_time': array([0.00293422, 0.00310254, 0.00236082, 0.0023427 , 0.00244403]),
#  'score_time': array([0.00949216, 0.03530788, 0.01654339, 0.01629376, 0.01826477]),
#  'test_score': array([0.96491228, 0.95614035, 0.98245614, 0.95614035, 0.96460177])}

# %%
param = {'n_neighbors' : [3,5,7],
         'weights' : ('uniform','distance'),'algorithm' : ('ball_tree','kd_tree','brute')}

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

model = KNeighborsClassifier()

gs = GridSearchCV(
    model,
    param_grid = param,
    n_jobs = multiprocessing.cpu_count(),
    cv = 5,
    verbose = True
)

gs.fit(X, y)
print("best estimator:{}, best score: {}".format(gs.best_estimator_, gs.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# best estimator:KNeighborsClassifier(algorithm='ball_tree', n_neighbors=7), best score: 0.9683589504735289

# %%
model = KNeighborsClassifier(algorithm='ball_tree', n_neighbors=7)

# %%
t_SNE = TSNE(n_components=2)
X_comp = t_SNE.fit_transform(X)
X0, X1 = X_comp[:,0], X_comp[:,1]
xx, yy = make_meshgrid(X0, X1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
model.fit(X_comp, y)
plot_contours(model, xx, yy, cmap=plt.cm.coolwarm, alpha=0.7)
plt.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k');

# %% [markdown]
# #KNN Regression

# %% [markdown]
# ## Example 1 - California Housing - KNN Regressor

# %%
california = fetch_california_housing()

# %%
california_df = pd.DataFrame(data=california.data, columns=california.feature_names)
california_df['Target'] = california.target
california_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  ...  AveOccup  Latitude  Longitude  Target
# 0  8.3252      41.0  6.984127   1.023810  ...  2.555556     37.88    -122.23   4.526
# 1  8.3014      21.0  6.238137   0.971880  ...  2.109842     37.86    -122.22   3.585
# 2  7.2574      52.0  8.288136   1.073446  ...  2.802260     37.85    -122.24   3.521
# 3  5.6431      52.0  5.817352   1.073059  ...  2.547945     37.85    -122.25   3.413
# 4  3.8462      52.0  6.281853   1.081081  ...  2.181467     37.85    -122.25   3.422
#
# [5 rows x 9 columns]

# %%
X, y = california.data, california.target
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
scaler = StandardScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

# %%
model = KNeighborsRegressor()
model.fit(X_train, y_train)

print("Score for the train set: {}".format(model.score(X_train, y_train)))
print("Score for the test set: {}".format(model.score(X_test, y_test)))
# Out:
# Score for the train set: 0.45177759294184916
# Score for the test set: 0.1616526449495368

# %%
model = KNeighborsRegressor()
model.fit(X_train_scale, y_train)

print("Score for the train set: {}".format(model.score(X_train_scale, y_train)))
print("Score for the test set: {}".format(model.score(X_test_scale, y_test)))
# Out:
# Score for the train set: 0.7935082760751918
# Score for the test set: 0.6764481714552064

# %%
estimator = make_pipeline(
    StandardScaler(),
    KNeighborsRegressor()
)

cross_validate(estimator=estimator, X=X, y=y, cv=5,
               n_jobs=multiprocessing.cpu_count(),
               verbose=True)
# Out:
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   5 out of   5 | elapsed:    2.8s finished
# {'fit_time': array([0.06001544, 0.06944919, 0.06082892, 0.082937  , 0.06101346]),
#  'score_time': array([0.83763313, 0.69095659, 0.69407964, 0.9792304 , 1.1553123 ]),
#  'test_score': array([0.47879396, 0.4760079 , 0.57624554, 0.50259828, 0.57228584])}

# %%
param = {'n_neighbors' : [3,5,7],
         'weights' : ('uniform','distance'),'algorithm' : ('ball_tree','kd_tree','brute')}

gs = GridSearchCV(
    estimator = KNeighborsRegressor(),
    param_grid = param,
    n_jobs = multiprocessing.cpu_count(),
    cv = 5,
    verbose = True
)

gs.fit(X, y)
print("best estimator:{}, best score: {}".format(gs.best_estimator_, gs.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:705: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# best estimator:KNeighborsRegressor(algorithm='ball_tree', n_neighbors=7, weights='distance'), best score: 0.043714530433925904

# %%
t_SNE = TSNE(n_components=1)
X_comp = t_SNE.fit_transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
model = KNeighborsRegressor(algorithm='ball_tree', n_neighbors=7, weights='distance')
model.fit(X_comp, y)
predict = model.predict(X_comp)

# %%
plt.scatter(X_comp, y, c='b', cmap=plt.cm.coolwarm, s=20, edgecolors='k')
plt.scatter(X_comp, predict, c='r', cmap=plt.cm.coolwarm, s=20, edgecolors='k');
